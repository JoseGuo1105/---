# %% [markdown]
# 第一阶段的任务是赛题理解和BaseLine。
# 1、首先下载官方提供的BaseLine,并且获取数据
# 首先选择“使用天池实验室打比赛”，点击“新建notebook”，生成自己的Notebook。按天池的加载数据说明， 点击挂载数据按钮，遇到挂载失败问题。这时从赛题与数据页面下载md文件数据到本地。md文件用记事本打开，得到数据文件下载路径。下载数据文件到本地。
# 在天池页面中的notebook中， 点击编辑，进行DSW界面。创建data文件夹。点击数据上传，将下载到本地的数据上传到data文件夹。
# ![image.png](attachment:image.png)
# 2、修改BaseLine中错误的代码，并调试。
#  1）使用shift+Enter键，在DSW中一步步运行Notebook中的代码。
#  2）发现异常，Import顺序错误，修改如下：
#  ![image-2.png](attachment:image-2.png)
#  3）Save文件出错，路径找不到。原文代码如下

# %% [markdown]
# # data_path = './data_raw/'
# data_path = '/home/admin/jupyter/data/' # 天池平台路径
# save_path = '/home/admin/jupyter/temp_results/'  # 天池平台路径

# %% [markdown]
# 在DSW中创建一个temp_results文件夹，继续运行代码。完成后将在temp_results文件夹下生成两个文件：
# ![image.png](attachment:image.png)

# %% [markdown]
# 文件itemcf_baseline_11-25.csv即是最终结果
# ![image.png](attachment:image.png)
# csv文件中共生成50000条用户数据，每个用户生成5个推荐文章，推荐概率按顺序排列。
# 下一步即是提交结果。将itemcf_baseline_11-25.csv下载到本地，并且在“提交结果”页面点提交
# ![image-2.png](attachment:image-2.png)
# 下面就可以看你的成绩了
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# Baseline的代码运行后的成绩只能达到0.1026，后续我会不断优化代码
